# %% [markdown]
# # PB016: Artificial intelligence I, labs 9 - Examples of working with knowledge representation frameworks in code
#
# This week's topic is representation of knowledge using ontologies and graphical models. We'll focus namely on:
#
# 1. __Working with a sample ontology__
# 2. __Working with a sample Bayesian network__

# %% [markdown]
# ---
#
# ## 1. Working with a sample [ontology](https://en.wikipedia.org/wiki/Ontology_%28information_science%29) - pizza time!
#
# ![pizza](https://www.fi.muni.cz/~novacek/courses/pb016/labs/img/pizza.jpg)
#
# __Basic facts__
# - Ontologies are machine-readable formalizations of general or domain knowledge. They typically address the following:
#   - representation, formal naming and definition of general categories (also called concepts or classes) and sets of specific entities that fall under these categories (these entities are usually called individuals, instances or objects);
#   - properties of the categories and individual entities;
#   - relationships between categories and individuals (super- and sub-classes, instances of classes);
#   - metadata and annotations that do not affect the logical interpretation (i.e., formal meaning) of the elements of the ontology, but can be useful for people and applications working with the ontology.
# - The formal basis of ontologies is usually propositional and/or first-order predicate logic (FOL), or rather its decidable subsets and/or extensions (e.g., fuzzy or probabilistic).
# - No tractable formalism uses the full range of possibilities of FOL (even the less expressive variants of languages ​​for the representation of ontologies are relatively demanding in terms of reasoning complexity).
# - In these labs we will deal with ontologies represented in the [OWL](https://en.wikipedia.org/wiki/Web_Ontology_Language) language, which is the "flagship" of the [W3C standard](https://www.w3.org/standards/semanticweb/) for [semantic web](https://en.wikipedia.org/wiki/Semantic_Web), based on [descriptive logic](https://en.wikipedia.org/wiki/Description_logic) (an extensively researched and relatively widely used formalism, especially in the [knowledge representation and reasoning](https://en.wikipedia.org/wiki/Knowledge_representation_and_reasoning) community).

# %% [markdown]
# ### __Installing [owlready2](https://owlready2.readthedocs.io/en/latest/)__

# %%
# installation and import of a package for working with ontologies;
# for details, see: https://owlready2.readthedocs.io/

# !pip install owlready2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting owlready2
#   Using cached owlready2-0.47.tar.gz (27.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: owlready2
#   Building wheel for owlready2 (pyproject.toml) ... done
#   Created wheel for owlready2: filename=owlready2-0.47-cp311-cp311-linux_x86_64.whl size=24582288 sha256=7a972da0276db8fa6acbe76399b6b359550dcd206ea273369d208109d17d6fc5
#   Stored in directory: /home/jindmen/.cache/pip/wheels/25/9a/a3/fb1ac6339caa859c8bb18d685736168b0b51d851af13d81d52
# Successfully built owlready2
# Installing collected packages: owlready2
# Successfully installed owlready2-0.47
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %% [markdown]
# ### __Loading a sample [pizza ontology](https://protege.stanford.edu/ontologies/pizza/pizza.owl)__

# %%
from owlready2 import *

PIZZA_URL = 'https://protege.stanford.edu/ontologies/pizza/pizza.owl'
PIZZA_NAMESPACE = 'http://www.co-ode.org/ontologies/pizza/pizza.owl'
onto_ns = get_namespace(PIZZA_NAMESPACE)

onto = get_ontology(PIZZA_URL).load()

# %% [markdown]
# ### __Listing items in the ontology__
# - Ontologies behave like classic Python objects in `owlready2`.
# - Their elements can be accessed using the "dot" notation, it is possible to iterate over them, their methods can be called, some objects have operators defined, etc.
# - Searching for explicitly defined elements is possible using the `search ()` function, which does not use any inference, but is still relatively [powerful](https://owlready2.readthedocs.io/en/latest/onto.html#simple-queries) (it supports searching for sub-classes, wild cards, filtering by element properties, nested search, etc.).

# %%
print('List of classes and their direct sub-classes:\n')

# iterating over the top-level ontology classes
for onto_class in onto.classes():
    print(onto_class, '(%s)' % onto_class.iri)

    # iterating over the sub-classes of the current class, their listing
    for sub_class in onto.search(subclass_of=onto_class):
        print('  sub-class:', sub_class)

print('\n'+'-'*80+'\n')
print('List of individuals in the loaded ontology:\n')

# iterating over the ontology individuals
for individual in onto.individuals():
    print(individual)

print('\n'+'-'*80+'\n')
print('List of object properties in the loaded ontology:\n')

# iterating over the object properties in the ontology
for onto_property in onto.object_properties():
    print(onto_property)
# Out:
# List of classes and their direct sub-classes:
#
# pizza.Pizza (http://www.co-ode.org/ontologies/pizza/pizza.owl#Pizza)
#   sub-class: pizza.Pizza
#   sub-class: pizza.NamedPizza
#   sub-class: pizza.UnclosedPizza
#   sub-class: pizza.American
#   sub-class: pizza.AmericanHot
#   sub-class: pizza.Cajun
#   sub-class: pizza.Capricciosa
#   sub-class: pizza.Caprina
#   sub-class: pizza.Fiorentina
#   sub-class: pizza.FourSeasons
#   sub-class: pizza.FruttiDiMare
#   sub-class: pizza.Giardiniera
#   sub-class: pizza.LaReine
#   sub-class: pizza.Margherita
#   sub-class: pizza.Mushroom
#   sub-class: pizza.Napoletana
#   sub-class: pizza.Parmense
#   sub-class: pizza.PolloAdAstra
#   sub-class: pizza.PrinceCarlo
#   sub-class: pizza.QuattroFormaggi
#   sub-class: pizza.Rosa
#   sub-class: pizza.Siciliana
#   sub-class: pizza.SloppyGiuseppe
#   sub-class: pizza.Soho
#   sub-class: pizza.Veneziana
# pizza.PizzaBase (http://www.co-ode.org/ontologies/pizza/pizza.owl#PizzaBase)
#   sub-class: pizza.PizzaBase
#   sub-class: pizza.DeepPanBase
#   sub-class: pizza.ThinAndCrispyBase
# pizza.Food (http://www.co-ode.org/ontologies/pizza/pizza.owl#Food)
#   sub-class: pizza.Food
#   sub-class: pizza.Pizza
#   sub-class: pizza.PizzaBase
#   sub-class: pizza.PizzaTopping
#   sub-class: pizza.IceCream
#   sub-class: pizza.NamedPizza
#   sub-class: pizza.UnclosedPizza
#   sub-class: pizza.DeepPanBase
#   sub-class: pizza.ThinAndCrispyBase
#   sub-class: pizza.FishTopping
#   sub-class: pizza.VegetableTopping
#   sub-class: pizza.HerbSpiceTopping
#   sub-class: pizza.CheeseTopping
#   sub-class: pizza.MeatTopping
#   sub-class: pizza.FruitTopping
#   sub-class: pizza.NutTopping
#   sub-class: pizza.SauceTopping
#   sub-class: pizza.American
#   sub-class: pizza.AmericanHot
#   sub-class: pizza.Cajun
#   sub-class: pizza.Capricciosa
#   sub-class: pizza.Caprina
#   sub-class: pizza.Fiorentina
#   sub-class: pizza.FourSeasons
#   sub-class: pizza.FruttiDiMare
#   sub-class: pizza.Giardiniera
#   sub-class: pizza.LaReine
#   sub-class: pizza.Margherita
#   sub-class: pizza.Mushroom
#   sub-class: pizza.Napoletana
#   sub-class: pizza.Parmense
#   sub-class: pizza.PolloAdAstra
#   sub-class: pizza.PrinceCarlo
#   sub-class: pizza.QuattroFormaggi
#   sub-class: pizza.Rosa
#   sub-class: pizza.Siciliana
#   sub-class: pizza.SloppyGiuseppe
#   sub-class: pizza.Soho
#   sub-class: pizza.Veneziana
#   sub-class: pizza.AnchoviesTopping
#   sub-class: pizza.PrawnsTopping
#   sub-class: pizza.MixedSeafoodTopping
#   sub-class: pizza.TomatoTopping
#   sub-class: pizza.ArtichokeTopping
#   sub-class: pizza.AsparagusTopping
#   sub-class: pizza.OnionTopping
#   sub-class: pizza.CaperTopping
#   sub-class: pizza.OliveTopping
#   sub-class: pizza.CheeseyVegetableTopping
#   sub-class: pizza.GarlicTopping
#   sub-class: pizza.SpinachTopping
#   sub-class: pizza.MushroomTopping
#   sub-class: pizza.LeekTopping
#   sub-class: pizza.PetitPoisTopping
#   sub-class: pizza.PepperTopping
#   sub-class: pizza.RocketTopping
#   sub-class: pizza.CajunSpiceTopping
#   sub-class: pizza.RosemaryTopping
#   sub-class: pizza.MozzarellaTopping
#   sub-class: pizza.GoatsCheeseTopping
#   sub-class: pizza.ParmesanTopping
#   sub-class: pizza.FourCheesesTopping
#   sub-class: pizza.GorgonzolaTopping
#   sub-class: pizza.PeperoniSausageTopping
#   sub-class: pizza.HamTopping
#   sub-class: pizza.ChickenTopping
#   sub-class: pizza.HotSpicedBeefTopping
#   sub-class: pizza.SultanaTopping
#   sub-class: pizza.PineKernels
#   sub-class: pizza.TobascoPepperSauce
#   sub-class: pizza.SundriedTomatoTopping
#   sub-class: pizza.SlicedTomatoTopping
#   sub-class: pizza.RedOnionTopping
#   sub-class: pizza.JalapenoPepperTopping
#   sub-class: pizza.PeperonataTopping
#   sub-class: pizza.GreenPepperTopping
#   sub-class: pizza.SweetPepperTopping
#   sub-class: pizza.ParmaHamTopping
#   sub-class: pizza.HotGreenPepperTopping
# pizza.Spiciness (http://www.co-ode.org/ontologies/pizza/pizza.owl#Spiciness)
#   sub-class: pizza.Spiciness
#   sub-class: pizza.Mild
#   sub-class: pizza.Hot
#   sub-class: pizza.Medium
# pizza.PizzaTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#PizzaTopping)
#   sub-class: pizza.PizzaTopping
#   sub-class: pizza.FishTopping
#   sub-class: pizza.VegetableTopping
#   sub-class: pizza.HerbSpiceTopping
#   sub-class: pizza.CheeseTopping
#   sub-class: pizza.MeatTopping
#   sub-class: pizza.FruitTopping
#   sub-class: pizza.NutTopping
#   sub-class: pizza.SauceTopping
#   sub-class: pizza.AnchoviesTopping
#   sub-class: pizza.PrawnsTopping
#   sub-class: pizza.MixedSeafoodTopping
#   sub-class: pizza.TomatoTopping
#   sub-class: pizza.ArtichokeTopping
#   sub-class: pizza.AsparagusTopping
#   sub-class: pizza.OnionTopping
#   sub-class: pizza.CaperTopping
#   sub-class: pizza.OliveTopping
#   sub-class: pizza.CheeseyVegetableTopping
#   sub-class: pizza.GarlicTopping
#   sub-class: pizza.SpinachTopping
#   sub-class: pizza.MushroomTopping
#   sub-class: pizza.LeekTopping
#   sub-class: pizza.PetitPoisTopping
#   sub-class: pizza.PepperTopping
#   sub-class: pizza.RocketTopping
#   sub-class: pizza.CajunSpiceTopping
#   sub-class: pizza.RosemaryTopping
#   sub-class: pizza.MozzarellaTopping
#   sub-class: pizza.GoatsCheeseTopping
#   sub-class: pizza.ParmesanTopping
#   sub-class: pizza.FourCheesesTopping
#   sub-class: pizza.GorgonzolaTopping
#   sub-class: pizza.PeperoniSausageTopping
#   sub-class: pizza.HamTopping
#   sub-class: pizza.ChickenTopping
#   sub-class: pizza.HotSpicedBeefTopping
#   sub-class: pizza.SultanaTopping
#   sub-class: pizza.PineKernels
#   sub-class: pizza.TobascoPepperSauce
#   sub-class: pizza.SundriedTomatoTopping
#   sub-class: pizza.SlicedTomatoTopping
#   sub-class: pizza.RedOnionTopping
#   sub-class: pizza.JalapenoPepperTopping
#   sub-class: pizza.PeperonataTopping
#   sub-class: pizza.GreenPepperTopping
#   sub-class: pizza.SweetPepperTopping
#   sub-class: pizza.ParmaHamTopping
#   sub-class: pizza.HotGreenPepperTopping
# pizza.American (http://www.co-ode.org/ontologies/pizza/pizza.owl#American)
#   sub-class: pizza.American
# pizza.NamedPizza (http://www.co-ode.org/ontologies/pizza/pizza.owl#NamedPizza)
#   sub-class: pizza.NamedPizza
#   sub-class: pizza.American
#   sub-class: pizza.AmericanHot
#   sub-class: pizza.Cajun
#   sub-class: pizza.Capricciosa
#   sub-class: pizza.Caprina
#   sub-class: pizza.Fiorentina
#   sub-class: pizza.FourSeasons
#   sub-class: pizza.FruttiDiMare
#   sub-class: pizza.Giardiniera
#   sub-class: pizza.LaReine
#   sub-class: pizza.Margherita
#   sub-class: pizza.Mushroom
#   sub-class: pizza.Napoletana
#   sub-class: pizza.Parmense
#   sub-class: pizza.PolloAdAstra
#   sub-class: pizza.PrinceCarlo
#   sub-class: pizza.QuattroFormaggi
#   sub-class: pizza.Rosa
#   sub-class: pizza.Siciliana
#   sub-class: pizza.SloppyGiuseppe
#   sub-class: pizza.Soho
#   sub-class: pizza.Veneziana
# pizza.MozzarellaTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#MozzarellaTopping)
#   sub-class: pizza.MozzarellaTopping
# pizza.PeperoniSausageTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#PeperoniSausageTopping)
#   sub-class: pizza.PeperoniSausageTopping
# pizza.TomatoTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#TomatoTopping)
#   sub-class: pizza.TomatoTopping
#   sub-class: pizza.SundriedTomatoTopping
#   sub-class: pizza.SlicedTomatoTopping
# pizza.AmericanHot (http://www.co-ode.org/ontologies/pizza/pizza.owl#AmericanHot)
#   sub-class: pizza.AmericanHot
# pizza.HotGreenPepperTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#HotGreenPepperTopping)
#   sub-class: pizza.HotGreenPepperTopping
# pizza.JalapenoPepperTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#JalapenoPepperTopping)
#   sub-class: pizza.JalapenoPepperTopping
# pizza.AnchoviesTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#AnchoviesTopping)
#   sub-class: pizza.AnchoviesTopping
# pizza.FishTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#FishTopping)
#   sub-class: pizza.FishTopping
#   sub-class: pizza.AnchoviesTopping
#   sub-class: pizza.PrawnsTopping
#   sub-class: pizza.MixedSeafoodTopping
# pizza.ArtichokeTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#ArtichokeTopping)
#   sub-class: pizza.ArtichokeTopping
# pizza.VegetableTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetableTopping)
#   sub-class: pizza.VegetableTopping
#   sub-class: pizza.TomatoTopping
#   sub-class: pizza.ArtichokeTopping
#   sub-class: pizza.AsparagusTopping
#   sub-class: pizza.OnionTopping
#   sub-class: pizza.CaperTopping
#   sub-class: pizza.OliveTopping
#   sub-class: pizza.CheeseyVegetableTopping
#   sub-class: pizza.GarlicTopping
#   sub-class: pizza.SpinachTopping
#   sub-class: pizza.MushroomTopping
#   sub-class: pizza.LeekTopping
#   sub-class: pizza.PetitPoisTopping
#   sub-class: pizza.PepperTopping
#   sub-class: pizza.RocketTopping
#   sub-class: pizza.SundriedTomatoTopping
#   sub-class: pizza.SlicedTomatoTopping
#   sub-class: pizza.RedOnionTopping
#   sub-class: pizza.JalapenoPepperTopping
#   sub-class: pizza.PeperonataTopping
#   sub-class: pizza.GreenPepperTopping
#   sub-class: pizza.SweetPepperTopping
#   sub-class: pizza.HotGreenPepperTopping
# pizza.Mild (http://www.co-ode.org/ontologies/pizza/pizza.owl#Mild)
#   sub-class: pizza.Mild
# pizza.AsparagusTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#AsparagusTopping)
#   sub-class: pizza.AsparagusTopping
# pizza.Cajun (http://www.co-ode.org/ontologies/pizza/pizza.owl#Cajun)
#   sub-class: pizza.Cajun
# pizza.OnionTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#OnionTopping)
#   sub-class: pizza.OnionTopping
#   sub-class: pizza.RedOnionTopping
# pizza.PeperonataTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#PeperonataTopping)
#   sub-class: pizza.PeperonataTopping
# pizza.PrawnsTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#PrawnsTopping)
#   sub-class: pizza.PrawnsTopping
# pizza.TobascoPepperSauce (http://www.co-ode.org/ontologies/pizza/pizza.owl#TobascoPepperSauce)
#   sub-class: pizza.TobascoPepperSauce
# pizza.CajunSpiceTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#CajunSpiceTopping)
#   sub-class: pizza.CajunSpiceTopping
# pizza.HerbSpiceTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#HerbSpiceTopping)
#   sub-class: pizza.HerbSpiceTopping
#   sub-class: pizza.CajunSpiceTopping
#   sub-class: pizza.RosemaryTopping
# pizza.Hot (http://www.co-ode.org/ontologies/pizza/pizza.owl#Hot)
#   sub-class: pizza.Hot
# pizza.RosemaryTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#RosemaryTopping)
#   sub-class: pizza.RosemaryTopping
# pizza.CaperTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#CaperTopping)
#   sub-class: pizza.CaperTopping
# pizza.Capricciosa (http://www.co-ode.org/ontologies/pizza/pizza.owl#Capricciosa)
#   sub-class: pizza.Capricciosa
# pizza.HamTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#HamTopping)
#   sub-class: pizza.HamTopping
#   sub-class: pizza.ParmaHamTopping
# pizza.OliveTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#OliveTopping)
#   sub-class: pizza.OliveTopping
# pizza.Caprina (http://www.co-ode.org/ontologies/pizza/pizza.owl#Caprina)
#   sub-class: pizza.Caprina
# pizza.GoatsCheeseTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#GoatsCheeseTopping)
#   sub-class: pizza.GoatsCheeseTopping
# pizza.SundriedTomatoTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#SundriedTomatoTopping)
#   sub-class: pizza.SundriedTomatoTopping
# pizza.CheeseTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseTopping)
#   sub-class: pizza.CheeseTopping
#   sub-class: pizza.MozzarellaTopping
#   sub-class: pizza.GoatsCheeseTopping
#   sub-class: pizza.CheeseyVegetableTopping
#   sub-class: pizza.ParmesanTopping
#   sub-class: pizza.FourCheesesTopping
#   sub-class: pizza.GorgonzolaTopping
# pizza.CheeseyPizza (http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyPizza)
#   sub-class: pizza.CheeseyPizza
# pizza.CheeseyVegetableTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#CheeseyVegetableTopping)
#   sub-class: pizza.CheeseyVegetableTopping
# pizza.ChickenTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#ChickenTopping)
#   sub-class: pizza.ChickenTopping
# pizza.MeatTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatTopping)
#   sub-class: pizza.MeatTopping
#   sub-class: pizza.PeperoniSausageTopping
#   sub-class: pizza.HamTopping
#   sub-class: pizza.ChickenTopping
#   sub-class: pizza.HotSpicedBeefTopping
#   sub-class: pizza.ParmaHamTopping
# pizza.Country (http://www.co-ode.org/ontologies/pizza/pizza.owl#Country)
#   sub-class: pizza.Country
# pizza.DomainConcept (http://www.co-ode.org/ontologies/pizza/pizza.owl#DomainConcept)
#   sub-class: pizza.DomainConcept
#   sub-class: pizza.Food
#   sub-class: pizza.Pizza
#   sub-class: pizza.PizzaBase
#   sub-class: pizza.PizzaTopping
#   sub-class: pizza.IceCream
#   sub-class: pizza.NamedPizza
#   sub-class: pizza.UnclosedPizza
#   sub-class: pizza.DeepPanBase
#   sub-class: pizza.ThinAndCrispyBase
#   sub-class: pizza.FishTopping
#   sub-class: pizza.VegetableTopping
#   sub-class: pizza.HerbSpiceTopping
#   sub-class: pizza.CheeseTopping
#   sub-class: pizza.MeatTopping
#   sub-class: pizza.FruitTopping
#   sub-class: pizza.NutTopping
#   sub-class: pizza.SauceTopping
#   sub-class: pizza.American
#   sub-class: pizza.AmericanHot
#   sub-class: pizza.Cajun
#   sub-class: pizza.Capricciosa
#   sub-class: pizza.Caprina
#   sub-class: pizza.Fiorentina
#   sub-class: pizza.FourSeasons
#   sub-class: pizza.FruttiDiMare
#   sub-class: pizza.Giardiniera
#   sub-class: pizza.LaReine
#   sub-class: pizza.Margherita
#   sub-class: pizza.Mushroom
#   sub-class: pizza.Napoletana
#   sub-class: pizza.Parmense
#   sub-class: pizza.PolloAdAstra
#   sub-class: pizza.PrinceCarlo
#   sub-class: pizza.QuattroFormaggi
#   sub-class: pizza.Rosa
#   sub-class: pizza.Siciliana
#   sub-class: pizza.SloppyGiuseppe
#   sub-class: pizza.Soho
#   sub-class: pizza.Veneziana
#   sub-class: pizza.AnchoviesTopping
#   sub-class: pizza.PrawnsTopping
#   sub-class: pizza.MixedSeafoodTopping
#   sub-class: pizza.TomatoTopping
#   sub-class: pizza.ArtichokeTopping
#   sub-class: pizza.AsparagusTopping
#   sub-class: pizza.OnionTopping
#   sub-class: pizza.CaperTopping
#   sub-class: pizza.OliveTopping
#   sub-class: pizza.CheeseyVegetableTopping
#   sub-class: pizza.GarlicTopping
#   sub-class: pizza.SpinachTopping
#   sub-class: pizza.MushroomTopping
#   sub-class: pizza.LeekTopping
#   sub-class: pizza.PetitPoisTopping
#   sub-class: pizza.PepperTopping
#   sub-class: pizza.RocketTopping
#   sub-class: pizza.CajunSpiceTopping
#   sub-class: pizza.RosemaryTopping
#   sub-class: pizza.MozzarellaTopping
#   sub-class: pizza.GoatsCheeseTopping
#   sub-class: pizza.ParmesanTopping
#   sub-class: pizza.FourCheesesTopping
#   sub-class: pizza.GorgonzolaTopping
#   sub-class: pizza.PeperoniSausageTopping
#   sub-class: pizza.HamTopping
#   sub-class: pizza.ChickenTopping
#   sub-class: pizza.HotSpicedBeefTopping
#   sub-class: pizza.SultanaTopping
#   sub-class: pizza.PineKernels
#   sub-class: pizza.TobascoPepperSauce
#   sub-class: pizza.SundriedTomatoTopping
#   sub-class: pizza.SlicedTomatoTopping
#   sub-class: pizza.RedOnionTopping
#   sub-class: pizza.JalapenoPepperTopping
#   sub-class: pizza.PeperonataTopping
#   sub-class: pizza.GreenPepperTopping
#   sub-class: pizza.SweetPepperTopping
#   sub-class: pizza.ParmaHamTopping
#   sub-class: pizza.HotGreenPepperTopping
# pizza.DeepPanBase (http://www.co-ode.org/ontologies/pizza/pizza.owl#DeepPanBase)
#   sub-class: pizza.DeepPanBase
# pizza.ThinAndCrispyBase (http://www.co-ode.org/ontologies/pizza/pizza.owl#ThinAndCrispyBase)
#   sub-class: pizza.ThinAndCrispyBase
# pizza.ValuePartition (http://www.co-ode.org/ontologies/pizza/pizza.owl#ValuePartition)
#   sub-class: pizza.ValuePartition
#   sub-class: pizza.Spiciness
#   sub-class: pizza.Mild
#   sub-class: pizza.Hot
#   sub-class: pizza.Medium
# pizza.Fiorentina (http://www.co-ode.org/ontologies/pizza/pizza.owl#Fiorentina)
#   sub-class: pizza.Fiorentina
# pizza.GarlicTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#GarlicTopping)
#   sub-class: pizza.GarlicTopping
# pizza.ParmesanTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#ParmesanTopping)
#   sub-class: pizza.ParmesanTopping
# pizza.SpinachTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#SpinachTopping)
#   sub-class: pizza.SpinachTopping
# pizza.FourCheesesTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#FourCheesesTopping)
#   sub-class: pizza.FourCheesesTopping
# pizza.FourSeasons (http://www.co-ode.org/ontologies/pizza/pizza.owl#FourSeasons)
#   sub-class: pizza.FourSeasons
# pizza.MushroomTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#MushroomTopping)
#   sub-class: pizza.MushroomTopping
# pizza.FruitTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#FruitTopping)
#   sub-class: pizza.FruitTopping
#   sub-class: pizza.SultanaTopping
# pizza.FruttiDiMare (http://www.co-ode.org/ontologies/pizza/pizza.owl#FruttiDiMare)
#   sub-class: pizza.FruttiDiMare
# pizza.MixedSeafoodTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#MixedSeafoodTopping)
#   sub-class: pizza.MixedSeafoodTopping
# pizza.Medium (http://www.co-ode.org/ontologies/pizza/pizza.owl#Medium)
#   sub-class: pizza.Medium
# pizza.Giardiniera (http://www.co-ode.org/ontologies/pizza/pizza.owl#Giardiniera)
#   sub-class: pizza.Giardiniera
# pizza.LeekTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#LeekTopping)
#   sub-class: pizza.LeekTopping
# pizza.PetitPoisTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#PetitPoisTopping)
#   sub-class: pizza.PetitPoisTopping
# pizza.SlicedTomatoTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#SlicedTomatoTopping)
#   sub-class: pizza.SlicedTomatoTopping
# pizza.GorgonzolaTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#GorgonzolaTopping)
#   sub-class: pizza.GorgonzolaTopping
# pizza.GreenPepperTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#GreenPepperTopping)
#   sub-class: pizza.GreenPepperTopping
#   sub-class: pizza.HotGreenPepperTopping
# pizza.PepperTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#PepperTopping)
#   sub-class: pizza.PepperTopping
#   sub-class: pizza.JalapenoPepperTopping
#   sub-class: pizza.PeperonataTopping
#   sub-class: pizza.GreenPepperTopping
#   sub-class: pizza.SweetPepperTopping
#   sub-class: pizza.HotGreenPepperTopping
# pizza.HotSpicedBeefTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#HotSpicedBeefTopping)
#   sub-class: pizza.HotSpicedBeefTopping
# pizza.IceCream (http://www.co-ode.org/ontologies/pizza/pizza.owl#IceCream)
#   sub-class: pizza.IceCream
# pizza.InterestingPizza (http://www.co-ode.org/ontologies/pizza/pizza.owl#InterestingPizza)
#   sub-class: pizza.InterestingPizza
# pizza.LaReine (http://www.co-ode.org/ontologies/pizza/pizza.owl#LaReine)
#   sub-class: pizza.LaReine
# pizza.Margherita (http://www.co-ode.org/ontologies/pizza/pizza.owl#Margherita)
#   sub-class: pizza.Margherita
# pizza.MeatyPizza (http://www.co-ode.org/ontologies/pizza/pizza.owl#MeatyPizza)
#   sub-class: pizza.MeatyPizza
# pizza.Mushroom (http://www.co-ode.org/ontologies/pizza/pizza.owl#Mushroom)
#   sub-class: pizza.Mushroom
# pizza.Napoletana (http://www.co-ode.org/ontologies/pizza/pizza.owl#Napoletana)
#   sub-class: pizza.Napoletana
# pizza.NonVegetarianPizza (http://www.co-ode.org/ontologies/pizza/pizza.owl#NonVegetarianPizza)
#   sub-class: pizza.NonVegetarianPizza
# pizza.VegetarianPizza (http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizza)
#   sub-class: pizza.VegetarianPizza
# pizza.NutTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#NutTopping)
#   sub-class: pizza.NutTopping
#   sub-class: pizza.PineKernels
# pizza.ParmaHamTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#ParmaHamTopping)
#   sub-class: pizza.ParmaHamTopping
# pizza.Parmense (http://www.co-ode.org/ontologies/pizza/pizza.owl#Parmense)
#   sub-class: pizza.Parmense
# pizza.PineKernels (http://www.co-ode.org/ontologies/pizza/pizza.owl#PineKernels)
#   sub-class: pizza.PineKernels
# pizza.PolloAdAstra (http://www.co-ode.org/ontologies/pizza/pizza.owl#PolloAdAstra)
#   sub-class: pizza.PolloAdAstra
# pizza.RedOnionTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#RedOnionTopping)
#   sub-class: pizza.RedOnionTopping
# pizza.SweetPepperTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#SweetPepperTopping)
#   sub-class: pizza.SweetPepperTopping
# pizza.PrinceCarlo (http://www.co-ode.org/ontologies/pizza/pizza.owl#PrinceCarlo)
#   sub-class: pizza.PrinceCarlo
# pizza.QuattroFormaggi (http://www.co-ode.org/ontologies/pizza/pizza.owl#QuattroFormaggi)
#   sub-class: pizza.QuattroFormaggi
# pizza.RealItalianPizza (http://www.co-ode.org/ontologies/pizza/pizza.owl#RealItalianPizza)
#   sub-class: pizza.RealItalianPizza
# pizza.RocketTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#RocketTopping)
#   sub-class: pizza.RocketTopping
# pizza.Rosa (http://www.co-ode.org/ontologies/pizza/pizza.owl#Rosa)
#   sub-class: pizza.Rosa
# pizza.SauceTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#SauceTopping)
#   sub-class: pizza.SauceTopping
#   sub-class: pizza.TobascoPepperSauce
# pizza.Siciliana (http://www.co-ode.org/ontologies/pizza/pizza.owl#Siciliana)
#   sub-class: pizza.Siciliana
# pizza.SloppyGiuseppe (http://www.co-ode.org/ontologies/pizza/pizza.owl#SloppyGiuseppe)
#   sub-class: pizza.SloppyGiuseppe
# pizza.Soho (http://www.co-ode.org/ontologies/pizza/pizza.owl#Soho)
#   sub-class: pizza.Soho
# pizza.SpicyPizza (http://www.co-ode.org/ontologies/pizza/pizza.owl#SpicyPizza)
#   sub-class: pizza.SpicyPizza
# pizza.SpicyTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#SpicyTopping)
#   sub-class: pizza.SpicyTopping
# pizza.SpicyPizzaEquivalent (http://www.co-ode.org/ontologies/pizza/pizza.owl#SpicyPizzaEquivalent)
#   sub-class: pizza.SpicyPizzaEquivalent
# pizza.SultanaTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#SultanaTopping)
#   sub-class: pizza.SultanaTopping
# pizza.ThinAndCrispyPizza (http://www.co-ode.org/ontologies/pizza/pizza.owl#ThinAndCrispyPizza)
#   sub-class: pizza.ThinAndCrispyPizza
# pizza.UnclosedPizza (http://www.co-ode.org/ontologies/pizza/pizza.owl#UnclosedPizza)
#   sub-class: pizza.UnclosedPizza
# pizza.VegetarianPizzaEquivalent1 (http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizzaEquivalent1)
#   sub-class: pizza.VegetarianPizzaEquivalent1
# pizza.VegetarianTopping (http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianTopping)
#   sub-class: pizza.VegetarianTopping
# pizza.VegetarianPizzaEquivalent2 (http://www.co-ode.org/ontologies/pizza/pizza.owl#VegetarianPizzaEquivalent2)
#   sub-class: pizza.VegetarianPizzaEquivalent2
# pizza.Veneziana (http://www.co-ode.org/ontologies/pizza/pizza.owl#Veneziana)
#   sub-class: pizza.Veneziana
#
# --------------------------------------------------------------------------------
#
# List of individuals in the loaded ontology:
#
# pizza.America
# pizza.England
# pizza.France
# pizza.Germany
# pizza.Italy
#
# --------------------------------------------------------------------------------
#
# List of object properties in the loaded ontology:
#
# pizza.hasBase
# pizza.hasIngredient
# pizza.isBaseOf
# pizza.hasCountryOfOrigin
# pizza.isIngredientOf
# pizza.hasSpiciness
# pizza.hasTopping
# pizza.isToppingOf

# %% [markdown]
# ### __Creating a new pizza (olomuciana)__
# - The pizza will be represented by a new `Olomuciana` class.
# - The base will be thin (Neapolitan style, i.e., `ThinAndCrispyBase`) and the pizza will have the following toppings:
#   - `TomatoTopping` (existing);
#   - `OnionTopping` (existing);
#   - `PaprikaTopping` (non-existent, must be created);
#   - `TvargleTopping` (non-existent, must be created).
# - To be upfront towards the customers, it would probably also be a good idea to create a new `PungencyLevel` category (similar to the existing` Spiciness` class), which can have one of the following values:
#   - `BlandAndBoring`;
#   - `MildlyAromatic`;
#   - `PrettyRipe`;
#   - `IsThereARottingCorpseInTheCellarOrWhat`.
# - Finally, one also needs to create a new `hasPungency` property that assigns `PungencyLevel` to `Pizza` objects.

# %%
# we work with the loaded ontology
with onto:

    # adding new classes defined as Python classes/objects, inheriting from
    # their corresponding super-classes - access to existing classes is
    # mediated via the object "onto_ns", which is a specific namespace (de
    # facto a domain, within which the given names of classes, individuals,
    # properties, etc. apply), in which they are ontology elements defined

    class PaprikaTopping(onto_ns.VegetableTopping):
        # inherits from the existing class of vegetable toppings
        pass

    class TvargleTopping(onto_ns.CheeseTopping):
        # inherits from the existing class of cheese toppings
        pass

    class PungencyLevel(Thing):
        # inherits from a special "top" class - everything is a type of "Thing"
        pass

    class BlandAndBoring(PungencyLevel):
        # inherits from the new class
        pass

    class MildlyAromatic(PungencyLevel):
        # inherits from the new class
        pass

    class PrettyRipe(PungencyLevel):
        # inherits from the new class
        pass

    class IsThereARottingCorpseInTheCellarOrWhat(PungencyLevel):
        # inherits from the new class
        pass

    # defining the mutual disjointness of the various "PungencyLevel" values

    AllDisjoint([BlandAndBoring, MildlyAromatic, PrettyRipe,
                 IsThereARottingCorpseInTheCellarOrWhat])

    # adding the new property that assigns the pungency to particular pizzas
    # NOTE: the operator >> defines the domain and range of the property,
    # respectively

    class hasPungency(onto_ns.Pizza >> PungencyLevel):
        pass

    # finally, we create the class representing the new pizza

    class Olomuciana(onto_ns.Pizza):
        # the base type
        hasBase = [onto_ns.ThinAndCrispyBase]
        # specific ingedients assigned to the pizza using a previously
        # existing property
        hasTopping = [onto_ns.TomatoTopping, TvargleTopping,
                      onto_ns.OnionTopping, PaprikaTopping]
        # specific pungency level
        hasPungency = [IsThereARottingCorpseInTheCellarOrWhat]


# checking the newly created elements
print('Our new pizza (general class)       :\n ', Olomuciana,
      '(%s)' % Olomuciana.iri)
# creating an instance of the new pizza
straight_from_the_oven = Olomuciana('freshly_baked_Olomuciana')
print('Our new pizza (specific baked pizza):\n ', straight_from_the_oven,
      '(%s)' % straight_from_the_oven.iri)

# adding the newly created elements to the namespace of the original Pizza
# ontology
for element in [PaprikaTopping, TvargleTopping, PungencyLevel, BlandAndBoring,
                MildlyAromatic, PrettyRipe,
                IsThereARottingCorpseInTheCellarOrWhat, hasPungency,
                Olomuciana, straight_from_the_oven]:
    element.namespace = onto_ns

# listing the sub-classes of the original and newly created classes of the
# pizza features
print('Sub-classes of the pizza feature classes:')
print('- sub-classes of the original "Spiciness" class:')
for subclass in onto_ns.Spiciness.subclasses():
    print('   ', subclass, '(%s)' % subclass.iri)
print('- sub-classes of the new "PungencyLevel" class:')
for subclass in PungencyLevel.subclasses():
    print('   ', subclass, '(%s)' % subclass.iri)
# Out:
# Our new pizza (general class)       :
#   pizza.Olomuciana (http://www.co-ode.org/ontologies/pizza/Olomuciana)
# Our new pizza (specific baked pizza):
#   pizza.freshly_baked_Olomuciana (http://www.co-ode.org/ontologies/pizza/freshly_baked_Olomuciana)
# Sub-classes of the pizza feature classes:
# - sub-classes of the original "Spiciness" class:
#     pizza.Mild (http://www.co-ode.org/ontologies/pizza/pizza.owl#Mild)
#     pizza.Hot (http://www.co-ode.org/ontologies/pizza/pizza.owl#Hot)
#     pizza.Medium (http://www.co-ode.org/ontologies/pizza/pizza.owl#Medium)
# - sub-classes of the new "PungencyLevel" class:
#     pizza.BlandAndBoring (http://www.co-ode.org/ontologies/pizza/pizza.owl#BlandAndBoring)
#     pizza.MildlyAromatic (http://www.co-ode.org/ontologies/pizza/pizza.owl#MildlyAromatic)
#     pizza.PrettyRipe (http://www.co-ode.org/ontologies/pizza/pizza.owl#PrettyRipe)
#     pizza.IsThereARottingCorpseInTheCellarOrWhat (http://www.co-ode.org/ontologies/pizza/pizza.owl#IsThereARottingCorpseInTheCellarOrWhat)

# %% [markdown]
# ### __Defining a class restriction__
# - Restrictions specify the meaning of classes beyond their position in a taxonomy, etc. - it is possible, for instance, to define restrictions on the cardinality of class properties, etc.
#   - An example is a simple pizza (`SimplePizza`), which has a maximum of three toppings.

# %%
with onto:
    class SimplePizza(onto_ns.Pizza): # inherits from an existing class Pizza
        # it's equivalent to an intersection of all pizza classes a classes that have up to three toppings
        equivalent_to = [onto_ns.Pizza & onto_ns.hasTopping.max(3,onto_ns.PizzaTopping)]

# %% [markdown]
# ### __Defining a property restriction__
# - Creating a new `hasDiameter` property specifying the diameter of a specific pizza.
# - Ensuring that the pizza can only have one diameter (e.g., one of 18cm, 23cm, 28cm or 33cm).
#
# A note on the solution: The `OneOf` construct is used to explicitly define instances of the` Diameter` class, which is the range of the `hasDiameter` property. Alternatively, one could use the built-in OWL type `FunctionalProperty`, which defines properties with just one possible value. For more details, see [this](https://owlready2.readthedocs.io/en/latest/restriction.html#one-of-constructs) or [this](https://owlready2.readthedocs.io/en/latest/properties.html#functional-and-inverse-functional-properties) part of the Owlready2 manual.

# %%
with onto:

    # creating a new pizza diameter class

    class Diameter(Thing):
        pass

    # defining the individuals representing different diameters

    small = Diameter('small=18cm')
    medium = Diameter('medium=23cm')
    large = Diameter('large=28cm')
    monster = Diameter('monster=33cm')

    # explicit restriction of the diameter class to a list of possible individuals

    Diameter.is_a.append(OneOf([small, medium, large, monster]))

    # defining the functional property hasDiameter

    class hasDiameter(ObjectProperty, FunctionalProperty):
        domain = [onto_ns.Pizza]
        range = [Diameter]

# listing the details of the new pizza
print('New class:', onto.Diameter)
small_pizza = onto_ns.Pizza('small_pizza')
print('New pizza instance:', small_pizza)
small_pizza.hasDiameter = small
print('Diameter of the new pizza instance:', small_pizza.hasDiameter)
# Out:
# New class: pizza.Diameter
# New pizza instance: pizza.small_pizza
# Diameter of the new pizza instance: pizza.small=18cm

# %% [markdown]
# ### __Classification of the pizza ontology by the [HermiT](http://www.hermit-reasoner.com/) reasoner__
# - Derivation of implicit facts based on description logic and materialization of the corresponding updated taxonomic structure.
# - Possible invalidation of inconsistent classes by adding an explicit statement that they are equivalent to "nothing" (but only if they are empty, i.e., if they have no instances; otherwise the whole process will fail).

# %%
with onto:
    sync_reasoner()
# Out:
# * Owlready2 * Running HermiT...
#     java -Xmx2000M -cp /home/jindmen/.local/lib/python3.11/site-packages/owlready2/hermit:/home/jindmen/.local/lib/python3.11/site-packages/owlready2/hermit/HermiT.jar org.semanticweb.HermiT.cli.CommandLine -c -O -D -I file:////tmp/tmpuu9ka660
# * Owlready2 * HermiT took 2.635690450668335 seconds
# * Owlready * Equivalenting: pizza.VegetarianPizzaEquivalent1 pizza.VegetarianPizzaEquivalent2
# * Owlready * Equivalenting: pizza.VegetarianPizzaEquivalent2 pizza.VegetarianPizzaEquivalent1
# * Owlready * Equivalenting: pizza.CheeseyVegetableTopping owl.Nothing
# * Owlready * Equivalenting: pizza.IceCream owl.Nothing
# * Owlready * Equivalenting: pizza.SpicyPizza pizza.SpicyPizzaEquivalent
# * Owlready * Equivalenting: pizza.SpicyPizzaEquivalent pizza.SpicyPizza
# * Owlready * Reparenting pizza.ThinAndCrispyPizza: {owl.Thing} => {pizza.Pizza}
# * Owlready * Reparenting pizza.NonVegetarianPizza: {owl.Thing} => {pizza.Pizza}
# * Owlready * Reparenting pizza.InterestingPizza: {owl.Thing} => {pizza.Pizza}
# * Owlready * Reparenting pizza.VegetarianPizza: {owl.Thing} => {pizza.Pizza}
# * Owlready * Reparenting pizza.SpicyPizzaEquivalent: {owl.Thing} => {pizza.Pizza}
# * Owlready * Reparenting pizza.SpicyPizza (since equivalent): {owl.Thing} => {pizza.Pizza}
# * Owlready * Reparenting pizza.CheeseyPizza: {owl.Thing} => {pizza.Pizza}
# * Owlready * Reparenting pizza.PrinceCarlo: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.InterestingPizza, pizza.VegetarianPizzaEquivalent1, pizza.NamedPizza}
# * Owlready * Reparenting pizza.Margherita: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.VegetarianPizzaEquivalent1, pizza.NamedPizza}
# * Owlready * Reparenting pizza.QuattroFormaggi: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.VegetarianPizzaEquivalent1, pizza.NamedPizza}
# * Owlready * Reparenting pizza.Mushroom: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.InterestingPizza, pizza.VegetarianPizzaEquivalent1, pizza.NamedPizza}
# * Owlready * Reparenting pizza.Rosa: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.InterestingPizza, pizza.VegetarianPizzaEquivalent1, pizza.NamedPizza}
# * Owlready * Reparenting pizza.Giardiniera: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.InterestingPizza, pizza.VegetarianPizzaEquivalent1, pizza.NamedPizza}
# * Owlready * Reparenting pizza.Fiorentina: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.InterestingPizza, pizza.VegetarianPizzaEquivalent1, pizza.NamedPizza}
# * Owlready * Reparenting pizza.Soho: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.InterestingPizza, pizza.VegetarianPizzaEquivalent1, pizza.NamedPizza}
# * Owlready * Reparenting pizza.Veneziana: {pizza.NamedPizza} => {pizza.RealItalianPizza, pizza.CheeseyPizza, pizza.NamedPizza, pizza.InterestingPizza, pizza.VegetarianPizzaEquivalent1}
# * Owlready * Reparenting pizza.Caprina: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.InterestingPizza, pizza.VegetarianPizzaEquivalent1, pizza.NamedPizza}
# * Owlready * Reparenting pizza.JalapenoPepperTopping: {pizza.PepperTopping} => {pizza.PepperTopping, pizza.SpicyTopping}
# * Owlready * Reparenting pizza.VegetableTopping: {pizza.PizzaTopping} => {pizza.VegetarianTopping}
# * Owlready * Reparenting pizza.FruitTopping: {pizza.PizzaTopping} => {pizza.VegetarianTopping}
# * Owlready * Reparenting pizza.CheeseTopping: {pizza.PizzaTopping} => {pizza.VegetarianTopping}
# * Owlready * Reparenting pizza.NutTopping: {pizza.PizzaTopping} => {pizza.VegetarianTopping}
# * Owlready * Reparenting pizza.HerbSpiceTopping: {pizza.PizzaTopping} => {pizza.VegetarianTopping}
# * Owlready * Reparenting pizza.SauceTopping: {pizza.PizzaTopping} => {pizza.VegetarianTopping}
# * Owlready * Reparenting pizza.Napoletana: {pizza.NamedPizza} => {pizza.RealItalianPizza, pizza.CheeseyPizza, pizza.NonVegetarianPizza, pizza.NamedPizza, pizza.InterestingPizza}
# * Owlready * Reparenting pizza.SloppyGiuseppe: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.SpicyPizza, pizza.MeatyPizza, pizza.NamedPizza, pizza.InterestingPizza}
# * Owlready * Reparenting pizza.FruttiDiMare: {pizza.NamedPizza} => {pizza.InterestingPizza, pizza.NonVegetarianPizza, pizza.NamedPizza}
# * Owlready * Reparenting pizza.Capricciosa: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.InterestingPizza, pizza.MeatyPizza, pizza.NamedPizza}
# * Owlready * Reparenting pizza.Siciliana: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.InterestingPizza, pizza.MeatyPizza, pizza.NamedPizza}
# * Owlready * Reparenting pizza.Parmense: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.InterestingPizza, pizza.MeatyPizza, pizza.NamedPizza}
# * Owlready * Reparenting pizza.PolloAdAstra: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.SpicyPizza, pizza.MeatyPizza, pizza.NamedPizza, pizza.InterestingPizza}
# * Owlready * Reparenting pizza.Cajun: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.SpicyPizza, pizza.NonVegetarianPizza, pizza.NamedPizza, pizza.InterestingPizza}
# * Owlready * Reparenting pizza.FourSeasons: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.InterestingPizza, pizza.MeatyPizza, pizza.NamedPizza}
# * Owlready * Reparenting pizza.American: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.InterestingPizza, pizza.MeatyPizza, pizza.NamedPizza}
# * Owlready * Reparenting pizza.LaReine: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.InterestingPizza, pizza.MeatyPizza, pizza.NamedPizza}
# * Owlready * Reparenting pizza.AmericanHot: {pizza.NamedPizza} => {pizza.CheeseyPizza, pizza.SpicyPizza, pizza.MeatyPizza, pizza.NamedPizza, pizza.InterestingPizza}
# * Owlready * Reparenting pizza.HotGreenPepperTopping: {pizza.GreenPepperTopping} => {pizza.GreenPepperTopping, pizza.SpicyTopping}
# * Owlready * Reparenting pizza.VegetarianTopping: {owl.Thing} => {pizza.PizzaTopping}
# * Owlready * Reparenting pizza.SpicyTopping: {owl.Thing} => {pizza.PizzaTopping}
# * Owlready * Reparenting pizza.TobascoPepperSauce: {pizza.SauceTopping} => {pizza.SauceTopping, pizza.SpicyTopping}
# * Owlready * Reparenting pizza.CajunSpiceTopping: {pizza.HerbSpiceTopping} => {pizza.HerbSpiceTopping, pizza.SpicyTopping}
# * Owlready * Reparenting pizza.VegetarianPizzaEquivalent2: {owl.Thing} => {pizza.VegetarianPizza}
# * Owlready * Reparenting pizza.VegetarianPizzaEquivalent1 (since equivalent): {owl.Thing} => {pizza.VegetarianPizza}
# * Owlready * Reparenting pizza.HotSpicedBeefTopping: {pizza.MeatTopping} => {pizza.MeatTopping, pizza.SpicyTopping}
# * Owlready * Reparenting pizza.Olomuciana: {pizza.Pizza} => {pizza.CheeseyPizza, pizza.InterestingPizza, pizza.ThinAndCrispyPizza}
# * Owlready * Reparenting pizza.MeatyPizza: {owl.Thing} => {pizza.NonVegetarianPizza}
# * Owlready * Reparenting pizza.Country: {owl.Thing} => {pizza.DomainConcept}
# * Owlready * Reparenting pizza.UnclosedPizza: {pizza.Pizza} => {pizza.CheeseyPizza}
# * Owlready * Reparenting pizza.RealItalianPizza: {owl.Thing} => {pizza.ThinAndCrispyPizza}
# * Owlready * Reparenting pizza.hasTopping: {owl.InverseFunctionalProperty, owl.ObjectProperty, pizza.hasIngredient} => {owl.InverseFunctionalProperty, pizza.hasIngredient}
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %% [markdown]
# ## 2. Working with a sample Bayesian network
#
# A [Bayesian network](https://en.wikipedia.org/wiki/Bayesian_network), Bayes network, belief network, Bayes(ian) model or probabilistic directed acyclic graphical model is defined as follows:
# - It is a probabilistic graphical model (a type of statistical model) that represents a set of random variables and their conditional dependencies via a directed acyclic graph (DAG).
# - The model is mostly used to represent causal relationship between the random variables.
# - Bayesian Networks are parameterized using [Conditional Probability Distributions](https://en.wikipedia.org/wiki/Conditional_probability_distribution) (CPD).
# - Each node in the network is parameterized using $P(node|Pa(node))$ where $Pa(node)$ represents the parents of node in the network.

# %% [markdown]
# ### __A sample Bayesian network__
# - student attribute (intelligence - I)
# - course attribute (difficulty - D)
# - grade (G)
# - recommendation letter attribute (positive/negative - L)
# - student's overall SAT score (positive/negative - S)
#
# ![Bayes Netwok](https://www.fi.muni.cz/~novacek/courses/pb016/labs/img/BN-example.png)

# %% [markdown]
# ### __Working with the sample network - installing [pgmpy](https://github.com/pgmpy/pgmpy)__

# %%
# !pip install pgmpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pgmpy
#   Downloading pgmpy-0.1.26-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: networkx in /home/jindmen/.local/lib/python3.11/site-packages (from pgmpy) (3.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pgmpy) (1.26.1)
# Requirement already satisfied: scipy in /home/jindmen/.local/lib/python3.11/site-packages (from pgmpy) (1.10.1)
# Requirement already satisfied: scikit-learn in /home/jindmen/.local/lib/python3.11/site-packages (from pgmpy) (1.4.1.post1)
# Requirement already satisfied: pandas in /home/jindmen/.local/lib/python3.11/site-packages (from pgmpy) (2.2.1)
# Requirement already satisfied: pyparsing in /usr/lib/python3/dist-packages (from pgmpy) (2.4.7)
# Collecting torch (from pgmpy)
#   Downloading torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting statsmodels (from pgmpy)
#   Downloading statsmodels-0.14.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: tqdm in /home/jindmen/.local/lib/python3.11/site-packages (from pgmpy) (4.66.4)
# Requirement already satisfied: joblib in /home/jindmen/.local/lib/python3.11/site-packages (from pgmpy) (1.3.2)
# Collecting opt-einsum (from pgmpy)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting xgboost (from pgmpy)
#   Downloading xgboost-2.1.2-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Collecting google-generativeai (from pgmpy)
#   Downloading google_generativeai-0.8.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting google-ai-generativelanguage==0.6.10 (from google-generativeai->pgmpy)
#   Downloading google_ai_generativelanguage-0.6.10-py3-none-any.whl.metadata (5.6 kB)
# Collecting google-api-core (from google-generativeai->pgmpy)
#   Downloading google_api_core-2.23.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-api-python-client (from google-generativeai->pgmpy)
#   Downloading google_api_python_client-2.154.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Collecting google-auth>=2.15.0 (from google-generativeai->pgmpy)
#   Downloading google_auth-2.36.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: protobuf in /usr/lib/python3/dist-packages (from google-generativeai->pgmpy) (3.12.4)
# Requirement already satisfied: pydantic in /home/jindmen/.local/lib/python3.11/site-packages (from google-generativeai->pgmpy) (2.7.1)
# Requirement already satisfied: typing-extensions in /home/jindmen/.local/lib/python3.11/site-packages (from google-generativeai->pgmpy) (4.11.0)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-ai-generativelanguage==0.6.10->google-generativeai->pgmpy)
#   Downloading proto_plus-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf (from google-generativeai->pgmpy)
#   Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jindmen/.local/lib/python3.11/site-packages (from pandas->pgmpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->pgmpy) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/jindmen/.local/lib/python3.11/site-packages (from pandas->pgmpy) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/jindmen/.local/lib/python3.11/site-packages (from scikit-learn->pgmpy) (3.4.0)
# Collecting patsy>=0.5.6 (from statsmodels->pgmpy)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in /home/jindmen/.local/lib/python3.11/site-packages (from statsmodels->pgmpy) (23.2)
# Collecting filelock (from torch->pgmpy)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: jinja2 in /home/jindmen/.local/lib/python3.11/site-packages (from torch->pgmpy) (3.1.3)
# Collecting fsspec (from torch->pgmpy)
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->pgmpy)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->pgmpy)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->pgmpy)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->pgmpy)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->pgmpy)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->pgmpy)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->pgmpy)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->pgmpy)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->pgmpy)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch->pgmpy)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch->pgmpy)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->pgmpy)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch->pgmpy)
#   Downloading triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch->pgmpy)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch->pgmpy)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core->google-generativeai->pgmpy)
#   Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /home/jindmen/.local/lib/python3.11/site-packages (from google-api-core->google-generativeai->pgmpy) (2.31.0)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=2.15.0->google-generativeai->pgmpy)
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=2.15.0->google-generativeai->pgmpy)
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=2.15.0->google-generativeai->pgmpy)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: six>=1.5 in /home/jindmen/.local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->pgmpy) (1.16.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/lib/python3/dist-packages (from google-api-python-client->google-generativeai->pgmpy) (0.20.2)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client->google-generativeai->pgmpy)
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client->google-generativeai->pgmpy)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jindmen/.local/lib/python3.11/site-packages (from jinja2->torch->pgmpy) (2.1.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/jindmen/.local/lib/python3.11/site-packages (from pydantic->google-generativeai->pgmpy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /home/jindmen/.local/lib/python3.11/site-packages (from pydantic->google-generativeai->pgmpy) (2.18.2)
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai->pgmpy)
#   Downloading grpcio-1.68.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai->pgmpy)
#   Downloading grpcio_status-1.68.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai->pgmpy)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jindmen/.local/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai->pgmpy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jindmen/.local/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai->pgmpy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jindmen/.local/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai->pgmpy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jindmen/.local/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai->pgmpy) (2024.2.2)
# Downloading pgmpy-0.1.26-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 21.5 MB/s eta 0:00:00
# Downloading google_generativeai-0.8.3-py3-none-any.whl (160 kB)
# Downloading google_ai_generativelanguage-0.6.10-py3-none-any.whl (760 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.0/760.0 kB 17.8 MB/s eta 0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading statsmodels-0.14.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 24.0 MB/s eta 0:00:00m eta 0:00:01:01
# Downloading torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl (906.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 14.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 19.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 16.4 MB/s eta 0:00:000:00:010:00:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 16.6 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 14.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 20.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 24.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 19.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 21.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 20.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 22.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 16.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 9.2 MB/s eta 0:00:0029.7 MB/s eta 0:00:01
# Downloading triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 21.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading xgboost-2.1.2-py3-none-manylinux_2_28_x86_64.whl (153.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.9/153.9 MB 22.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading google_api_core-2.23.0-py3-none-any.whl (156 kB)
# Downloading google_auth-2.36.0-py2.py3-none-any.whl (209 kB)
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Downloading google_api_python_client-2.154.0-py2.py3-none-any.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 16.8 MB/s eta 0:00:000:00:01m eta 0:00:01
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl (221 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 1.3 MB/s eta 0:00:000:00:01
# Downloading proto_plus-1.25.0-py3-none-any.whl (50 kB)
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading grpcio-1.68.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 13.6 MB/s eta 0:00:0031m32.8 MB/s eta 0:00:01
# Downloading grpcio_status-1.68.0-py3-none-any.whl (14 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: mpmath, uritemplate, sympy, pyasn1, protobuf, patsy, opt-einsum, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, grpcio, fsspec, filelock, cachetools, xgboost, triton, rsa, pyasn1-modules, proto-plus, nvidia-cusparse-cu12, nvidia-cudnn-cu12, googleapis-common-protos, statsmodels, nvidia-cusolver-cu12, grpcio-status, google-auth, torch, google-auth-httplib2, google-api-core, google-api-python-client, google-ai-generativelanguage, google-generativeai, pgmpy
# Successfully installed cachetools-5.5.0 filelock-3.16.1 fsspec-2024.10.0 google-ai-generativelanguage-0.6.10 google-api-core-2.23.0 google-api-python-client-2.154.0 google-auth-2.36.0 google-auth-httplib2-0.2.0 google-generativeai-0.8.3 googleapis-common-protos-1.66.0 grpcio-1.68.0 grpcio-status-1.68.0 mpmath-1.3.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 opt-einsum-3.4.0 patsy-1.0.1 pgmpy-0.1.26 proto-plus-1.25.0 protobuf-5.28.3 pyasn1-0.6.1 pyasn1-modules-0.4.1 rsa-4.9 statsmodels-0.14.4 sympy-1.13.1 torch-2.5.1 triton-3.1.0 uritemplate-4.1.1 xgboost-2.1.2
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %% [markdown]
# ### __Creating the model__

# %%
from pgmpy.models import BayesianNetwork
from pgmpy.factors.discrete import TabularCPD

# Defining the model structure. We can define the network by just passing a
# list of edges.
model = BayesianNetwork([('D', 'G'), ('I', 'G'), ('G', 'L'), ('I', 'S')])

# Defining individual CPDs.
cpd_d = TabularCPD(variable='D', variable_card=2, values=[[0.6], [0.4]])
cpd_i = TabularCPD(variable='I', variable_card=2, values=[[0.7], [0.3]])

# The representation of CPD in pgmpy is a bit different than the CPD shown in
# the above picture. In pgmpy the colums are the evidences and rows are the
# states of the variable. So the grade CPD is represented like this:
#
#    +---------+---------+---------+---------+---------+
#    | diff    | intel_0 | intel_0 | intel_1 | intel_1 |
#    +---------+---------+---------+---------+---------+
#    | intel   | diff_0  | diff_1  | diff_0  | diff_1  |
#    +---------+---------+---------+---------+---------+
#    | grade_0 | 0.3     | 0.05    | 0.9     | 0.5     |
#    +---------+---------+---------+---------+---------+
#    | grade_1 | 0.4     | 0.25    | 0.08    | 0.3     |
#    +---------+---------+---------+---------+---------+
#    | grade_2 | 0.3     | 0.7     | 0.02    | 0.2     |
#    +---------+---------+---------+---------+---------+

cpd_g = TabularCPD(variable='G', variable_card=3,
                   values=[[0.3, 0.05, 0.9,  0.5],
                           [0.4, 0.25, 0.08, 0.3],
                           [0.3, 0.7,  0.02, 0.2]],
                  evidence=['I', 'D'],
                  evidence_card=[2, 2])

cpd_l = TabularCPD(variable='L', variable_card=2,
                   values=[[0.1, 0.4, 0.99],
                           [0.9, 0.6, 0.01]],
                   evidence=['G'],
                   evidence_card=[3])

cpd_s = TabularCPD(variable='S', variable_card=2,
                   values=[[0.95, 0.2],
                           [0.05, 0.8]],
                   evidence=['I'],
                   evidence_card=[2])

# Associating the CPDs with the network
model.add_cpds(cpd_d, cpd_i, cpd_g, cpd_l, cpd_s)

# check_model checks for the network structure and CPDs and verifies that the
# CPDs are correctly defined and sum to 1.
model.check_model()
# Out:
# True

# %% [markdown]
# ### __Creating the model using state names__

# %%
# CPDs can also be defined using the state names of the variables. If the state
# names are not provided like in the previous example, pgmpy will automatically
# assign names as: 0, 1, 2, ....

cpd_d_sn = TabularCPD(variable='D', variable_card=2, values=[[0.6], [0.4]],
                      state_names={'D': ['Easy', 'Hard']})
cpd_i_sn = TabularCPD(variable='I', variable_card=2, values=[[0.7], [0.3]],
                      state_names={'I': ['Dumb', 'Intelligent']})
cpd_g_sn = TabularCPD(variable='G', variable_card=3,
                      values=[[0.3, 0.05, 0.9,  0.5],
                              [0.4, 0.25, 0.08, 0.3],
                              [0.3, 0.7,  0.02, 0.2]],
                      evidence=['I', 'D'],
                      evidence_card=[2, 2],
                      state_names={'G': ['A', 'B', 'C'],
                                   'I': ['Dumb', 'Intelligent'],
                                   'D': ['Easy', 'Hard']})

cpd_l_sn = TabularCPD(variable='L', variable_card=2,
                      values=[[0.1, 0.4, 0.99],
                              [0.9, 0.6, 0.01]],
                      evidence=['G'],
                      evidence_card=[3],
                      state_names={'L': ['Bad', 'Good'],
                                   'G': ['A', 'B', 'C']})

cpd_s_sn = TabularCPD(variable='S', variable_card=2,
                      values=[[0.95, 0.2],
                              [0.05, 0.8]],
                      evidence=['I'],
                      evidence_card=[2],
                      state_names={'S': ['Bad', 'Good'],
                                   'I': ['Dumb', 'Intelligent']})

# These defined CPDs can be added to the model. Since, the model already has
# CPDs associated to variables, it will show warning that pmgpy is now
# replacing those CPDs with the new ones.
model.add_cpds(cpd_d_sn, cpd_i_sn, cpd_g_sn, cpd_l_sn, cpd_s_sn)
model.check_model()
# Out:
# WARNING:pgmpy:Replacing existing CPD for D
# WARNING:pgmpy:Replacing existing CPD for I
# WARNING:pgmpy:Replacing existing CPD for G
# WARNING:pgmpy:Replacing existing CPD for L
# WARNING:pgmpy:Replacing existing CPD for S
# True

# %% [markdown]
# ### __Exploring the created model__

# %%
# We can now call some methods on the BayesianModel object.
model.get_cpds()
# Out:
# [<TabularCPD representing P(D:2) at 0x7675865b3050>,
#  <TabularCPD representing P(I:2) at 0x7675871c85d0>,
#  <TabularCPD representing P(G:3 | I:2, D:2) at 0x7675865b3610>,
#  <TabularCPD representing P(L:2 | G:3) at 0x7675865b3750>,
#  <TabularCPD representing P(S:2 | I:2) at 0x7675865b3dd0>]

# %%
# Printing a CPD which doesn't have state names defined.
print(cpd_g)
# Out:
# +------+------+------+------+------+
# | I    | I(0) | I(0) | I(1) | I(1) |
# +------+------+------+------+------+
# | D    | D(0) | D(1) | D(0) | D(1) |
# +------+------+------+------+------+
# | G(0) | 0.3  | 0.05 | 0.9  | 0.5  |
# +------+------+------+------+------+
# | G(1) | 0.4  | 0.25 | 0.08 | 0.3  |
# +------+------+------+------+------+
# | G(2) | 0.3  | 0.7  | 0.02 | 0.2  |
# +------+------+------+------+------+

# %%
# Printing a CPD with it's state names defined.
print(model.get_cpds('G'))
# Out:
# +------+---------+---------+----------------+----------------+
# | I    | I(Dumb) | I(Dumb) | I(Intelligent) | I(Intelligent) |
# +------+---------+---------+----------------+----------------+
# | D    | D(Easy) | D(Hard) | D(Easy)        | D(Hard)        |
# +------+---------+---------+----------------+----------------+
# | G(A) | 0.3     | 0.05    | 0.9            | 0.5            |
# +------+---------+---------+----------------+----------------+
# | G(B) | 0.4     | 0.25    | 0.08           | 0.3            |
# +------+---------+---------+----------------+----------------+
# | G(C) | 0.3     | 0.7     | 0.02           | 0.2            |
# +------+---------+---------+----------------+----------------+

# %%
model.get_cardinality('G')
# Out:
# 3

# %% [markdown]
# ### __Inference using the model__

# %%
from pgmpy.inference import VariableElimination
infer = VariableElimination(model)

# Grade probability when an intelligent student enrolls into an easy course
print(infer.query(['G'], evidence={'D': 'Easy', 'I': 'Intelligent'}))
print(infer.query(['L'], evidence={'D': 'Easy', 'I': 'Intelligent'}))
print(infer.query(['L'], evidence={'D': 'Hard', 'I': 'Intelligent'}))
# Out:
# +------+----------+
# | G    |   phi(G) |
# +======+==========+
# | G(A) |   0.9000 |
# +------+----------+
# | G(B) |   0.0800 |
# +------+----------+
# | G(C) |   0.0200 |
# +------+----------+
# +---------+----------+
# | L       |   phi(L) |
# +=========+==========+
# | L(Bad)  |   0.1418 |
# +---------+----------+
# | L(Good) |   0.8582 |
# +---------+----------+
# +---------+----------+
# | L       |   phi(L) |
# +=========+==========+
# | L(Bad)  |   0.3680 |
# +---------+----------+
# | L(Good) |   0.6320 |
# +---------+----------+

# %% [markdown]
# ---
#
# #### _Final note_ - the materials used in this notebook are adapted from original works authored as follows:
# - Example of pizza ontology:
#  - Retrieved from [Protege](https://protege.stanford.edu/)
#  - Author: Nick Drummond, Alan Rector, Matthew Horridge, Chris Wroe, Robert Stevens
#  - License: [CC BY 3.0](https://creativecommons.org/licenses/by/3.0/)
# - Pizza picture:
#  - Retrieved from [Wikimedia Commons](https://commons.wikimedia.org/wiki/File:Eq_it-na_pizza-margherita_sep2005_sml.jpg)
#  - Author: [Valerio Capello](https://en.wikipedia.org/wiki/User:ElfQrin)
#  - License: [CC BY-SA 3.0](https://creativecommons.org/licenses/by-sa/3.0/deed.en), [GNU Free Documenation License](https://en.wikipedia.org/wiki/en:GNU_Free_Documentation_License)
# - The `pgmpy`-related contents:
#  - Adapted from the `pgmpy` [Github site](https://github.com/pgmpy/pgmpy)
#  - Author: The `pgmpy` [contributors](https://github.com/pgmpy/pgmpy/graphs/contributors)
#  - License: [MIT](https://mit-license.org/)
